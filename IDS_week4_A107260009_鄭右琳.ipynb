# %% [markdown]
# <a href="https://colab.research.google.com/github/yoyo1022/Introduciton-to-Data-Science/blob/master/IDS_week4_A107260009_%E9%84%AD%E5%8F%B3%E7%90%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
current_Celsius = 25
Fahrenheit = current_Celsius*9/5+32
print(Fahrenheit)
# Out:
# 77.0

# %%
current_Fahrenheit = 77
Celsius = (Fahrenheit-32)*5/9
print(Celsius)
# Out:
# 25.0

# %%
shaq_weight = 147
shaq_height = 216
shaq_bmi = shaq_weight/(shaq_height/100)**2
print(shaq_bmi)
# Out:
# 31.507201646090532

# %%
ross_said = """Let's put aside the fact that you "accidentally" pick up my grandmother's ring."""
print(ross_said)
# Out:
# Let's put aside the fact that you "accidentally" pick up my grandmother's ring.

# %%
city = input("請輸入城市: " )
weather = input("請輸入天氣: " )
print("我在{}，天氣{}".format(city, weather))
# Out:
# 請輸入城市: 台北
# 請輸入天氣: 晴
# 我在台北，天氣晴

# %%
name = input("請輸入姓名: ")
shaq_height = eval(input("請輸入身高: "))
shaq_weight = eval(input("請輸入體重: "))
shaq_bmi = shaq_weight/(shaq_height/100)**2
print("{}的身體質量指數為：{:.2f}".format(name,shaq_bmi)) 
print("{}是否過重：{}".format(name,shaq_bmi > 30))
# Out:
# 請輸入姓名: 俠客歐尼爾
# 請輸入身高: 216
# 請輸入體重: 147
# 俠客歐尼爾 的身體質量指數為：31.51
# 俠客歐尼爾 是否過重：True
